# %%
import os
from google.cloud import bigquery
from datetime import datetime
import pandas_gbq
import pandas as pd
import random
import numpy as np

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/Alfred/Documents/Trabajo/Personal/los-outliers/Data/climate-prediction-389419-10c7097dc497.json"

# %%
def upload_dataframe_to_bigquery(dataframe, full_table_id):
    # Create a BigQuery client
    client = bigquery.Client()
    # Append the dataframe to the BigQuery table
    pandas_gbq.to_gbq(dataframe, full_table_id, if_exists='append', project_id='climate-prediction-389419')

# %%
# clean data function
def clean_data(file_path):
    df = pd.read_csv(file_path)
    df = df[['Year', 'Start Month', 'Country', 'Location', 'Disaster Type']]

    # Rename 'Start Month' column to 'Month'
    df.rename(columns={'Start Month': 'Month'}, inplace=True)

    # Create column with Precipitation (MM) random values between 0 and 100
    df['Precipitation_MM'] = df['Year'].apply(lambda x: random.randint(0, 100))

    # Create column with Temperature random values between -10 and 40
    df['Temperature'] = df['Year'].apply(lambda x: random.randint(-10, 40))

    # Drop null values in Location and Month
    df = df.dropna(subset=['Location', 'Month'])

    # Convert 'Year' to int
    df['Year'] = df['Year'].astype(int)

    # Create column with Disaster Probability (or prediction) random values between 0 and 1
    df['Disaster_Probability'] = df['Year'].apply(lambda x: random.random())

    # Replace spaces in column names with underscores
    df.columns = df.columns.str.replace(' ', '_')

    return df

# %%
df = clean_data('/Users/Alfred/Documents/Trabajo/Personal/los-outliers/Data/1900_2021_DISASTERS.xlsx - emdat data.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/02/dtm061vs7vq07sq99d8x3lxc0000gn/T/ipykernel_23197/66163700.py in <module>
# ----> 1 df = clean_data('/Users/Alfred/Documents/Trabajo/Personal/los-outliers/Data/1900_2021_DISASTERS.xlsx - emdat data.csv')
#
# /var/folders/02/dtm061vs7vq07sq99d8x3lxc0000gn/T/ipykernel_23197/3494625628.py in clean_data(file_path)
#      47                                'Disaster_Type': "No", 'Precipitation_MM': precip, 'Temperature': temp}
#      48                     # Add the row to the dataframe
# ---> 49                     df = df.append(new_row, ignore_index=True)
#      50
#      51     return df
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8967                 ignore_index=ignore_index,
#    8968                 verify_integrity=verify_integrity,
# -> 8969                 sort=sort,
#    8970             )
#    8971         ).__finalize__(self, method="append")
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     531
#     532             new_data = concatenate_managers(
# --> 533                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     534             )
#     535             if not self.copy:
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     207                 values = values.view()
#     208             fastpath = True
# --> 209         elif _is_uniform_join_units(join_units):
#     210             vals = [ju.block.values for ju in join_units]
#     211
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/internals/concat.py in _is_uniform_join_units(join_units)
#     605         # no blocks that would get missing values (can lead to type upcasts)
#     606         # unless we're an extension dtype.
# --> 607         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     608         and
#     609         # no blocks with indexers (as then the dimensions do not fit)
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/internals/concat.py in <genexpr>(.0)
#     605         # no blocks that would get missing values (can lead to type upcasts)
#     606         # unless we're an extension dtype.
# --> 607         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     608         and
#     609         # no blocks with indexers (as then the dimensions do not fit)
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/internals/concat.py in is_na(self)
#     399             values_flat = values.ravel(order="K")
#     400
# --> 401         return isna_all(values_flat)
#     402
#     403     def get_reindexed_values(self, empty_dtype: DtypeObj, upcasted_na) -> ArrayLike:
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in isna_all(arr)
#     678         # Sequence[Sequence[Any]], _SupportsArray]"
#     679         checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]
# --> 680         for i in range(0, total_len, chunk_len)
#     681     )
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in <genexpr>(.0)
#     678         # Sequence[Sequence[Any]], _SupportsArray]"
#     679         checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]
# --> 680         for i in range(0, total_len, chunk_len)
#     681     )
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in <lambda>(x)
#     669         # Any]", variable has type "ufunc")
#     670         checker = lambda x: _isna_array(  # type: ignore[assignment]
# --> 671             x, inf_as_na=INF_AS_NA
#     672         )
#     673
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in _isna_array(values, inf_as_na)
#     244             result = values.isna()
#     245     elif is_string_dtype(dtype):
# --> 246         result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     247     elif needs_i8_conversion(dtype):
#     248         # this is the NaT pattern
#
# ~/Documents/Trabajo/Personal/los-outliers/climate-ml/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in _isna_string_dtype(values, inf_as_na)
#     269             vec = libmissing.isnaobj_old(values.ravel())
#     270         else:
# --> 271             vec = libmissing.isnaobj(values.ravel())
#     272
#     273         result[...] = vec.reshape(shape)
#
# KeyboardInterrupt:

# %%
df.head(30)
# Out:
#     Year  Start_Month     Country  \
# 0   1900          NaN  Cabo Verde
# 1   1900          NaN       India
# 2   1902          4.0   Guatemala
# 5   1903          4.0      Canada
# 7   1904         11.0  Bangladesh
# 8   1905          8.0      Canada
# 9   1905          4.0       India
# 10  1906          8.0       Chile
# 11  1906          1.0    Colombia
# 12  1906          5.0     Belgium
# 15  1907         10.0       China
# 17  1908          4.0      Canada
# 18  1909         10.0  Bangladesh
# 19  1909         12.0  Bangladesh
# 21  1909          6.0      France
# 22  1909         11.0       Haiti
# 25  1910          3.0      Canada
# 26  1910          NaN       China
# 28  1910          4.0  Costa Rica
# 29  1910          6.0     Algeria
# 32  1911          4.0  Bangladesh
# 33  1911          7.0      Canada
# 35  1912          6.0      Canada
# 36  1912          8.0       China
# 37  1914          6.0   Indonesia
# 38  1915          3.0      Canada
# 39  1915          NaN       China
# 40  1915          8.0       Haiti
# 41  1916         11.0       India
# 42  1917          7.0       China
#
#                                              Location        Disaster_Type  \
# 0                                         Countrywide              Drought
# 1                                              Bengal              Drought
# 2                           Quezaltenango, San Marcos           Earthquake
# 5                                      Frank, Alberta  Mass movement (dry)
# 7                                          Chittagong                Storm
# 8                   Spence's Bridge, British Columbia  Mass movement (dry)
# 9                                              Kangra           Earthquake
# 10                                         Valparaiso           Earthquake
# 11                                             Tumako           Earthquake
# 12                                     Louvain region                Flood
# 15                                          Tien Shan           Earthquake
# 17                   Notre Dame de La Salette, Quebec  Mass movement (dry)
# 18                                          Bakerganj                Storm
# 19                                    West Sundarbans                Storm
# 21  Lambesc, Saint-Cannat, Rognes, Vernegues, Char...           Earthquake
# 22                                 Cul de Sac,Leogane                Storm
# 25                     Roger's Pass, British Columbia            Landslide
# 26                                          Manchuria             Epidemic
# 28                                            Cartago           Earthquake
# 29                                 Kabylie, Masqueray           Earthquake
# 32                                             Teknaf                Storm
# 33            Cochrane (and Northern Region), Ontario             Wildfire
# 35                               Regina, Saskatchewan                Storm
# 36                                            Wenchou                Storm
# 37                     Kepahyang, Bengkulu (Sumatera)           Earthquake
# 38                      Cooper Mine, British Columbia            Landslide
# 39                                          Guangzhou                Flood
# 40                              South, Southwest area                Storm
# 41                             Cuddalore, Pondicherry                Storm
# 42                                    Yunnan province           Earthquake
#
#     Precipitation_MM  Temperature  Disaster_Probability  \
# 0                 55            8              0.035097
# 1                 61           38              0.688285
# 2                 73           16              0.053360
# 5                 83           -2              0.242061
# 7                  5           12              0.609005
# 8                 32           19              0.162969
# 9                 29           13              0.582946
# 10                36           30              0.549397
# 11                42           22              0.816978
# 12                53            9              0.655348
# 15                31           -9              0.491905
# 17                76           23              0.429790
# 18                 8           10              0.394177
# 19                54            5              0.197574
# 21                42           39              0.797323
# 22                80           23              0.981705
# 25                 0           26              0.751198
# 26                58           -2              0.999092
# 28                65           -4              0.055193
# 29                45           32              0.050315
# 32                51           15              0.300845
# 33                74           33              0.192725
# 35                37           -4              0.544812
# 36                73            5              0.100766
# 37                66            3              0.222617
# 38                30            1              0.250431
# 39                46           23              0.679497
# 40                88           -1              0.096675
# 41                 6           19              0.105366
# 42                94           27              0.490644
#
#                                           Ciudad_Pais
# 0                             Countrywide, Cabo Verde
# 1                                       Bengal, India
# 2                Quezaltenango, San Marcos, Guatemala
# 5                              Frank, Alberta, Canada
# 7                              Chittagong, Bangladesh
# 8           Spence's Bridge, British Columbia, Canada
# 9                                       Kangra, India
# 10                                  Valparaiso, Chile
# 11                                   Tumako, Colombia
# 12                            Louvain region, Belgium
# 15                                   Tien Shan, China
# 17           Notre Dame de La Salette, Quebec, Canada
# 18                              Bakerganj, Bangladesh
# 19                        West Sundarbans, Bangladesh
# 21  Lambesc, Saint-Cannat, Rognes, Vernegues, Char...
# 22                          Cul de Sac,Leogane, Haiti
# 25             Roger's Pass, British Columbia, Canada
# 26                                   Manchuria, China
# 28                                Cartago, Costa Rica
# 29                        Kabylie, Masqueray, Algeria
# 32                                 Teknaf, Bangladesh
# 33    Cochrane (and Northern Region), Ontario, Canada
# 35                       Regina, Saskatchewan, Canada
# 36                                     Wenchou, China
# 37          Kepahyang, Bengkulu (Sumatera), Indonesia
# 38              Cooper Mine, British Columbia, Canada
# 39                                   Guangzhou, China
# 40                       South, Southwest area, Haiti
# 41                      Cuddalore, Pondicherry, India
# 42                             Yunnan province, China

# %%
# read csv file and save as dataframe
extended_df = pd.read_csv('/Users/Alfred/Documents/Trabajo/Personal/los-outliers/Data/extendido_1900_2021_DISASTERS.xlsx - emdat data.csv')
# rename precipitation column to Precipitation_MM
extended_df.rename(columns={'Precipitation_(MM)': 'Precipitation_MM'}, inplace=True)

# rename Disaster_Probability_(or_prediction) column to Disaster_Probability
extended_df.rename(columns={'Disaster_Probability_(or_prediction)': 'Disaster_Probability'}, inplace=True)

# %%
# Temperature under 5 is cold, between 5 and 25 is warm, and above 25 is hot
extended_df['Temperature'] = extended_df['Temperature'].apply(lambda x: 'cold' if x < 5 else 'warm' if 5 <= x <= 25 else 'hot')

# Precipitation under 10 is low, between 10 and 30 is medium, and above 30 is high
extended_df['Precipitation_MM'] = extended_df['Precipitation_MM'].apply(lambda x: 'low' if x < 10 else 'medium' if 10 <= x <= 30 else 'high')

# %%
extended_df.head()
# Out:
#    Year     Country                   Location  Month        Disaster_Type  \
# 0  1902   Guatemala  Quezaltenango, San Marcos    4.0           Earthquake
# 1  1902   Guatemala                        NaN    4.0    Volcanic activity
# 2  1902   Guatemala                        NaN   10.0    Volcanic activity
# 3  1903      Canada             Frank, Alberta    4.0  Mass movement (dry)
# 4  1904  Bangladesh                 Chittagong   11.0                Storm
#
#   Precipitation_MM Temperature  Disaster_Probability
# 0             high         hot                     1
# 1             high        warm                     1
# 2             high        cold                     1
# 3             high        cold                     1
# 4             high         hot                     1

# %%
upload_dataframe_to_bigquery(extended_df, 'climate-prediction-389419.climate_prediction.disasters')

# %%
from kats.consts import MultivariateTimeSeriesData
from kats.models.var import VARModel, VARParams
from typing import List

# define a list of variable names
value_vars: List[str] = ["Precipitation_(MM)", "Temperature", "Location", "Country", "Year", "Month", "Disaster_Type"]

# Iterar sobre las distintas categorias de "Location" en df_test
for location in df_test['Location'].unique():
    # Filtrar df_test por location
    df_location = df_test[df_test['Location'] == location]
    
    # create a MultivariateTimeSeriesData object
    multivariate_time_series = MultivariateTimeSeriesData(
        df=df_location, 
        time_col_name="Year", 
        value_col_names=value_vars
    )
    
    # Crear un objeto VARModel con serie_de_tiempo
    params=VARParams()
    m=VARModel(data=multivariate_time_series, params=params)
    
    # Entrenar el modelo
    m.fit()
    
    # Predecir la columna Disaster_Probability_(or_prediction) de df_location
    prediction = m.predict(steps=1)
    
    # Agregar la columna "Disaster_Probability_(or_prediction)" a df_location
    # assuming that Disaster_Probability is the first variable in the prediction
    df_location['Disaster_Probability_(or_prediction)'] = prediction.y[0]

    # Agregar df_location a df_test
    df_test = df_test.append(df_location)
